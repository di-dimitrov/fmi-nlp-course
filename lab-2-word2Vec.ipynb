# %% [markdown]
# # Word2Vec — Practical Session
#
#
# ## How do we convert test to a vector so far ?
# * One-hot encoding
# * Bag of words
# * TF-IDF
#
# **Problem:** Ignores semantic meaning/context. How do we identify sematically similar words?
#
# ---
#
# ### Background
#
# A **word embedding** maps each word in a vocabulary to a dense real-valued vector so that
# semantically similar words end up close together in that vector space.
#
# Word2Vec (Mikolov et al., 2013) offers two complementary architectures:
#
# | Architecture | Predict | From |
# |---|---|---|
# | **CBOW** (Continuous Bag-of-Words) | target word | surrounding context |
# | **Skip-gram** | surrounding context | target word |
#
# We implement **Skip-gram with Negative Sampling (SGNS)** — the most widely used variant.
#
# **Negative Sampling** replaces the expensive full-softmax over the vocabulary with a binary
# classification objective:
# - Maximise the probability that a *real* (target, context) pair co-occurred
# - Minimise the probability for *k* randomly sampled *negative* pairs
#
# $$\mathcal{L} = -\log \sigma(\mathbf{u}_{target} \cdot \mathbf{v}_{context}) - \sum_{i=1}^{k} \log \sigma(-\mathbf{u}_{target} \cdot \mathbf{v}_{neg_i})$$

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

from collections import Counter
import collections
import random
import string
from tqdm import tqdm

import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# ── Reproducibility ──────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %% [markdown]
# ---
# ## Part 1 — Data Loading & Exploration
#
# The dataset is a Bulgarian news corpus labelled for **subjectivity** (`SUBJ` / `OBJ`).
# We use the *text* only — the labels are irrelevant for unsupervised embedding training.

# %%
# ── Load all three splits ────────────────────────────────────────────────────
train_df = pd.read_csv('./fmi-nlp-course/data/train.csv')
val_df   = pd.read_csv('./fmi-nlp-course/data/val.csv')
test_df  = pd.read_csv('./fmi-nlp-course/data/test.csv')

print(f'Train : {train_df.shape[0]:>4} rows  |  {train_df["label"].value_counts().to_dict()}')
print(f'Val   : {val_df.shape[0]:>4} rows  |  {val_df["label"].value_counts().to_dict()}')
print(f'Test  : {test_df.shape[0]:>4} rows  |  {test_df["label"].value_counts().to_dict()}')

# Pool ALL sentences for embedding training (labels not used here)
all_sentences_df = pd.concat([train_df, val_df, test_df], ignore_index=True)
print(f'\nTotal sentences for embedding training: {len(all_sentences_df):,}')
all_sentences_df.head(5)
# Out:
# Train :  801 rows  |  {'OBJ': 440, 'SUBJ': 361}
# Val   :  246 rows  |  {'OBJ': 144, 'SUBJ': 102}
# Test  :  250 rows  |  {'OBJ': 143, 'SUBJ': 107}
#
# Total sentences for embedding training: 1,297
#                                      id  \
# 0  fde9e435-8186-4cb3-8ec1-1be67ddb5f96
# 1  bb522430-40f0-4781-9910-92a1aefd013b
# 2  d6a84f01-9153-4f3b-bca6-ed2b2edc6a9e
# 3  3623488a-c528-4509-a92d-9ad4b49099ec
# 4  587b0e27-6ac8-433f-9b99-adf8d9c7c0a2
#
#                                             sentence label
# 0  "Трудно е класически оркестър и рок банда да с...   OBJ
# 1  Следователно, Москва е пазителка на православн...   OBJ
# 2  От Washington Post са изготвили подробен матер...   OBJ
# 3  И пак така относно заслугите за постигнатото о...   OBJ
# 4  Понякога удобството да разтвориш набързо стран...   OBJ

# %%
# ── Label distribution across splits ────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(13, 4))
for ax, (name, df) in zip(axes, [('Train', train_df), ('Val', val_df), ('Test', test_df)]):
    counts = df['label'].value_counts()
    bars = ax.bar(counts.index, counts.values, color=['steelblue', 'coral'])
    ax.set_title(f'{name}  ({len(df)} rows)')
    ax.set_ylabel('Count')
    for bar, v in zip(bars, counts.values):
        ax.text(bar.get_x() + bar.get_width() / 2, v + 0.5, str(v),
                ha='center', fontweight='bold')
plt.suptitle('Label Distribution Across Splits', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Part 2 — Text Preprocessing
#
# ### 2.1 Tokenisation
#
# We tokenise each sentence with NLTK and remove punctuation tokens.
# The result is a flat list of all words in corpus order — this is our *training corpus*.

# %%
PUNCTUATION = set(string.punctuation) | {'``', "''", '...', '\u2013', '\u2014'}

word_data = []
# Use the pooled corpus (train + val + test) for richer embeddings
for sent in all_sentences_df['sentence'].values:
    tokens = word_tokenize(sent)
    tokens = [w for w in tokens if w not in PUNCTUATION]
    word_data.extend(tokens)

print(f'Total tokens after preprocessing: {len(word_data):,}')
print(f'Sample tokens: {word_data[:20]}')
# Out:
# Total tokens after preprocessing: 21,853
# Sample tokens: ['Трудно', 'е', 'класически', 'оркестър', 'и', 'рок', 'банда', 'да', 'свирят', 'заедно', 'имаме', 'физически', 'проблеми', 'защото', 'една', 'рок', 'група', 'колкото', 'и', 'да']

# %%
# ── Word frequency distribution ──────────────────────────────────────────────
freq = Counter(word_data)
unique_words = len(freq)
print(f'Unique word types: {unique_words:,}')

# Top-20 most common words
top20 = freq.most_common(20)
words_top, counts_top = zip(*top20)

plt.figure(figsize=(12, 4))
plt.bar(words_top, counts_top, color='steelblue')
plt.xticks(rotation=45, ha='right')
plt.title('Top-20 Most Frequent Words')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# Unique word types: 8,169

# %% [markdown]
# ### 2.2 Building the Vocabulary
#
# We keep only the top-`VOCAB_SIZE` most frequent words. All others become `UNK` (unknown).
#
# The function returns:
# - `data_indexed` — the corpus as a sequence of integer IDs
# - `count` — `[word, frequency]` pairs (UNK first)
# - `word2idx` — word → integer mapping
# - `idx2word` — integer → word mapping

# %%
VOCAB_SIZE = 5000   # Keep only top-5000 words (adjust to your corpus size)

def build_dataset(words: list, n_words: int):
    """
    Convert a flat word list into an integer-indexed corpus.

    Returns
    -------
    data         : list[int]  — corpus as word IDs
    count        : list[list] — [[word, freq], ...]
    word2idx     : dict       — word -> id
    idx2word     : dict       — id -> word
    """
    count = [['UNK', -1]]
    count.extend(Counter(words).most_common(n_words - 1))

    word2idx = {word: i for i, (word, _) in enumerate(count)}
    unk_idx  = word2idx['UNK']

    data, unk_count = [], 0
    for word in words:
        idx = word2idx.get(word, unk_idx)
        if idx == unk_idx:
            unk_count += 1
        data.append(idx)

    count[0][1] = unk_count
    idx2word = {v: k for k, v in word2idx.items()}
    return data, count, word2idx, idx2word


data_indexed, count, word2idx, idx2word = build_dataset(word_data, VOCAB_SIZE)

unk_count = count[0][1]
print(f'Vocabulary size  : {VOCAB_SIZE}')
print(f'Corpus length    : {len(data_indexed):,} tokens')
print(f'UNK tokens       : {unk_count:,} ({100*unk_count/len(data_indexed):.1f}%)')
print(f'\nFirst 10 token IDs: {data_indexed[:10]}')
print(f'Decoded           : {[idx2word[i] for i in data_indexed[:10]]}')
# Out:
# Vocabulary size  : 5000
# Corpus length    : 21,853 tokens
# UNK tokens       : 3,170 (14.5%)
#
# First 10 token IDs: [2090, 5, 2091, 2092, 2, 1011, 1012, 3, 2093, 651]
# Decoded           : ['Трудно', 'е', 'класически', 'оркестър', 'и', 'рок', 'банда', 'да', 'свирят', 'заедно']

# %% [markdown]
# ---
# ## Part 3 — Batch Generation (Skip-gram)
#
# The Skip-gram model predicts *context* words from a *target* word.
# For every target word we sample `num_skips` context words within a window of size `skip_window`.
#
# ```
# Corpus:   [w0, w1, w2, w3, w4, w5, w6]
# target:              w3
# window=2:        w1 w2 ** w4 w5
# pairs:   (w3,w1), (w3,w2), (w3,w4), (w3,w5)
# ```

# %%
data_index = 0   # Global cursor into the corpus

def generate_batch(batch_size: int, num_skips: int, skip_window: int):
    """
    Generate one training batch of (target, context) pairs.

    Parameters
    ----------
    batch_size  : number of pairs to return
    num_skips   : how many context words to sample per target  (≤ 2*skip_window)
    skip_window : half-size of the context window on each side

    Returns
    -------
    batch  : np.ndarray shape (batch_size, 1) — target word IDs
    labels : np.ndarray shape (batch_size, 1) — context word IDs
    """
    global data_index
    assert batch_size % num_skips == 0, 'batch_size must be divisible by num_skips'
    assert num_skips <= 2 * skip_window, 'num_skips cannot exceed 2 * skip_window'

    batch  = np.ndarray(shape=(batch_size, 1), dtype=np.longlong)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.longlong)

    span   = 2 * skip_window + 1          # total window width
    buffer = collections.deque(maxlen=span)

    if data_index + span > len(data_indexed):
        data_index = 0
    buffer.extend(data_indexed[data_index:data_index + span])
    data_index += span

    for i in range(batch_size // num_skips):
        context_positions = [p for p in range(span) if p != skip_window]
        chosen             = random.sample(context_positions, num_skips)
        for j, ctx_pos in enumerate(chosen):
            batch [i * num_skips + j]    = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[ctx_pos]

        if data_index == len(data_indexed):
            buffer.extend(data_indexed[:span])
            data_index = span
        else:
            buffer.append(data_indexed[data_index])
            data_index += 1

    data_index = (data_index + len(data_indexed) - span) % len(data_indexed)
    return batch, labels


data_index = 0
demo_batch, demo_labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

print(f'Example: {[idx2word[i] for i in data_indexed[:10]]}')
print('Target word  →  Context word')
print('-' * 35)
for t, c in zip(demo_batch[:, 0], demo_labels[:, 0]):
    print(f'  {idx2word[t]:20s}  →  {idx2word[c]}')
# Out:
# Example: ['Трудно', 'е', 'класически', 'оркестър', 'и', 'рок', 'банда', 'да', 'свирят', 'заедно']
# Target word  →  Context word
# -----------------------------------
#   е                     →  Трудно
#   е                     →  класически
#   класически            →  оркестър
#   класически            →  е
#   оркестър              →  класически
#   оркестър              →  и
#   и                     →  оркестър
#   и                     →  рок

# %% [markdown]
# **Discussion:** Why do we sample `num_skips` context words per target rather than using all of them?

# %% [markdown]
# ---
# ## Part 4 — The Skip-gram Model
#
# ### Architecture
#
# The model contains **two embedding matrices**:
# - `u_embeddings` (target / input embeddings)  — shape `[V, D]`
# - `v_embeddings` (context / output embeddings) — shape `[V, D]`
#
# Using two separate matrices avoids trivial solutions and is standard practice.
# After training we typically use `u_embeddings` as the final word vectors.
#
# ### Loss — Negative Sampling
#
# For a positive pair `(u, v)` and `k` negative samples `{n₁, …, nₖ}`:
#
# $$\mathcal{L} = -\log \sigma(\mathbf{u} \cdot \mathbf{v}) - \sum_{i=1}^{k} \log \sigma(-\mathbf{u} \cdot \mathbf{n_i})$$
#
# Clamping the scores to `[-10, 10]` prevents numerical overflow.

# %%
class SkipGram(nn.Module):
    """
    Skip-gram model with Negative Sampling.

    Parameters
    ----------
    vocab_size : size of the vocabulary V
    emb_size   : embedding dimensionality D
    """

    def __init__(self, vocab_size: int, emb_size: int):
        super().__init__()
        self.vocab_size = vocab_size
        self.emb_size   = emb_size

        # Two embedding tables — target (u) and context (v)
        self.u_embeddings = nn.Embedding(vocab_size, emb_size)
        self.v_embeddings = nn.Embedding(vocab_size, emb_size)

        # Initialise with small uniform noise (common practice)
        nn.init.uniform_(self.u_embeddings.weight, -0.5 / emb_size, 0.5 / emb_size)
        nn.init.constant_(self.v_embeddings.weight, 0.0)

    # ── Forward pass ──────────────────────────────────────────────────────
    def forward(self,
                target:          torch.Tensor,   # (B, 1)  — target word IDs
                context:         torch.Tensor,   # (B, 1)  — positive context IDs
                negative_sample: torch.Tensor    # (B, K)  — negative sample IDs
               ) -> torch.Tensor:
        """
        Compute the negative-sampling loss for one batch.

        Returns the mean loss over the batch (scalar).
        """
        # Look up embeddings  →  (B, 1, D)
        emb_u    = self.u_embeddings(target)           # target vectors
        emb_v    = self.v_embeddings(context)          # positive context vectors
        emb_neg  = self.v_embeddings(negative_sample)  # negative context vectors  (B, K, D)

        # ── Positive score: dot(u, v)  summed over D, shape (B,) ──────────
        pos_score = torch.sum(torch.mul(emb_u, emb_v), dim=2)      # (B, 1)
        pos_score = torch.clamp(pos_score, max=10, min=-10)
        pos_loss  = -F.logsigmoid(pos_score)                        # (B, 1)

        # ── Negative score: bmm(emb_neg, emb_u^T)  shape (B, K, 1) ───────
        neg_score = torch.bmm(emb_neg, emb_u.permute(0, 2, 1))     # (B, K, 1)
        neg_score = torch.clamp(neg_score, max=10, min=-10)
        neg_loss  = -torch.sum(F.logsigmoid(-neg_score), dim=1)     # (B, 1)

        return torch.mean(pos_loss + neg_loss)

    # ── Nearest-neighbour search ───────────────────────────────────────────
    @torch.no_grad()
    def get_nearest(self, word_ids: torch.Tensor, top_k: int = 8) -> torch.Tensor:
        """
        Return the indices of the top_k nearest neighbours (by cosine similarity)
        for each word ID in word_ids.

        Parameters
        ----------
        word_ids : LongTensor of shape (N, 1)
        top_k    : number of neighbours

        Returns
        -------
        LongTensor of shape (N, top_k) — indices of nearest neighbours
        """
        # Retrieve target embeddings and L2-normalise
        emb      = self.u_embeddings(word_ids.squeeze(1))      # (N, D)
        emb_norm = F.normalize(emb, p=2, dim=1)                # (N, D)

        # Full embedding matrix, L2-normalised
        all_emb  = F.normalize(self.u_embeddings.weight, p=2, dim=1)  # (V, D)

        # Cosine similarity matrix: (N, V)
        sim = torch.mm(emb_norm, all_emb.T)

        # top_k + 1 because the word itself will be included
        _, neighbour_ids = torch.topk(sim, top_k + 1, dim=1)
        return neighbour_ids[:, 1:]   # exclude the query word itself

    # ── Get a single embedding vector ─────────────────────────────────────
    @torch.no_grad()
    def get_embedding(self, word_id: int) -> np.ndarray:
        """Return the (D,) numpy embedding for a single word."""
        idx = torch.LongTensor([word_id]).to(device)
        return self.u_embeddings(idx).cpu().numpy()[0]


# ── Quick shape test ──────────────────────────────────────────────────────────
test_model = SkipGram(VOCAB_SIZE, 32)
t  = torch.LongTensor([[1], [2], [3]])
c  = torch.LongTensor([[4], [5], [6]])
ns = torch.LongTensor([[7, 8], [9, 10], [11, 12]])
loss_test = test_model(t, c, ns)
print(f'Test forward pass — loss value: {loss_test.item():.4f}')
print(t)
# Out:
# Test forward pass — loss value: 2.0794
# tensor([[1],
#         [2],
#         [3]])

# %% [markdown]
# ---
# ## Part 5 — Training
#
# ### Hyperparameters
#
# | Parameter | Value | Meaning |
# |---|---|---|
# | `EMBEDDING_DIM` | 100 | Vector dimensionality |
# | `BATCH_SIZE` | 256 | Pairs per gradient step |
# | `SKIP_WINDOW` | 3 | Context half-window |
# | `NUM_SKIPS` | 4 | Context samples per target |
# | `NUM_NEG` | 10 | Negative samples per positive |
# | `NUM_STEPS` | 10000 | Total training steps |
# | `LR` | 0.025 | SGD learning rate |

# %%
# ── Hyperparameters ───────────────────────────────────────────────────────────
EMBEDDING_DIM  = 100
BATCH_SIZE     = 256
SKIP_WINDOW    = 3
NUM_SKIPS      = 4     # must be ≤ 2 * SKIP_WINDOW
NUM_NEG        = 10    # negative samples per positive pair
NUM_STEPS      = 10000
LR             = 0.025

# Words to monitor during training (pick frequent, meaningful words)
VALID_WORDS    = ['България', 'Русия', 'Европа', 'война', 'хора', 'свят', 'Обама', 'Тръмп']
valid_ids      = [word2idx[w] for w in VALID_WORDS if w in word2idx]
valid_ids_np   = np.array(valid_ids).reshape(-1, 1)

print('Monitoring embeddings for:', [idx2word[i] for i in valid_ids])
# Out:
# Monitoring embeddings for: ['България', 'Русия', 'Европа', 'война', 'хора', 'свят', 'Обама', 'Тръмп']

# %%
# ── Helper: sample negatives ──────────────────────────────────────────────────
def sample_negatives(batch_size: int, vocab_size: int, k: int) -> np.ndarray:
    """
    Sample k negative word IDs for each item in the batch.
    Returns array of shape (batch_size, k).
    """
    return np.random.randint(0, vocab_size, (batch_size, k))


# ── Initialise model & optimiser ──────────────────────────────────────────────
model     = SkipGram(VOCAB_SIZE, EMBEDDING_DIM).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=LR)

print(model)
total_params = sum(p.numel() for p in model.parameters())
print(f'\nTotal trainable parameters: {total_params:,}')
# Out:
# SkipGram(
#   (u_embeddings): Embedding(5000, 100)
#   (v_embeddings): Embedding(5000, 100)
# )
#
# Total trainable parameters: 1,000,000

# %%
# ── Training loop ─────────────────────────────────────────────────────────────
data_index = 0  # Reset corpus cursor
model.train()

loss_history     = []
report_every     = 1000
running_loss     = 0.0

for step in tqdm(range(1, NUM_STEPS + 1)):
    optimizer.zero_grad()

    # ── Build batch ──────────────────────────────────────────────────────
    pos_u, pos_v = generate_batch(BATCH_SIZE, num_skips=NUM_SKIPS, skip_window=SKIP_WINDOW)
    neg_v        = sample_negatives(BATCH_SIZE, VOCAB_SIZE, NUM_NEG)

    pos_u = torch.LongTensor(pos_u).to(device)
    pos_v = torch.LongTensor(pos_v).to(device)
    neg_v = torch.LongTensor(neg_v).to(device)

    # ── Forward + backward ───────────────────────────────────────────────
    loss = model(pos_u, pos_v, neg_v)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()

    if step % report_every == 0:
        avg_loss = running_loss / report_every
        loss_history.append((step, avg_loss))
        running_loss = 0.0

        # Show nearest neighbours for validation words
        model.eval()
        val_tensor   = torch.LongTensor(valid_ids_np).to(device)
        neighbours   = model.get_nearest(val_tensor, top_k=5).cpu().numpy()
        model.train()

        print(f'\n── Step {step} | avg loss: {avg_loss:.4f}')
        for i, vid in enumerate(valid_ids):
            nb_words = [idx2word[n] for n in neighbours[i]]
            print(f'   {idx2word[vid]:15s} →  {nb_words}')

print('Training complete!')
# Out:
#  10%|█         | 1018/10000 [00:03<00:27, 324.30it/s]
# ── Step 1000 | avg loss: 7.6246
#    България        →  ['ние', 'способност', 'неговото', 'Сходен', 'регресирате']
#    Русия           →  ['съща', 'комисия', 'годишният', 'запомнят', 'нацията']
#    Европа          →  ['23.30', 'някак', 'политиката', 'обиколи', 'ИНТЕРЕС']
#    война           →  ['започнали', 'факт', 'конституционните', 'проблемът', 'мистерии']
#    хора            →  ['сценарист', 'Какво', 'получава', 'възможност', 'Далай']
#    свят            →  ['актрисата', 'арийския', 'Кинг', 'Леопардовото', 'филми']
#    Обама           →  ['слаби', 'правата', 'поклонения', '31', 'Девраха']
#    Тръмп           →  ['1994-та', 'никаква', 'християните', 'оформен', 'секунда']
#  20%|██        | 2013/10000 [00:10<02:09, 61.69it/s]
# ── Step 2000 | avg loss: 7.6246
#    България        →  ['ние', 'способност', 'неговото', 'регресирате', 'Сходен']
#    Русия           →  ['съща', 'комисия', 'годишният', 'запомнят', 'нацията']
# ...

# %%
# ── Plot training loss ────────────────────────────────────────────────────────
steps_plot, losses_plot = zip(*loss_history)

plt.figure(figsize=(10, 4))
plt.plot(steps_plot, losses_plot, marker='o', linewidth=2)
plt.xlabel('Training step')
plt.ylabel(f'Avg loss (over {report_every} steps)')
plt.title('Skip-gram Training Loss')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Part 6 — Working with Embeddings
#
# ### 6.1 Cosine Similarity
#
# The most natural way to compare word vectors is **cosine similarity**:
#
# $$\text{sim}(\mathbf{a}, \mathbf{b}) = \frac{\mathbf{a} \cdot \mathbf{b}}{\|\mathbf{a}\| \|\mathbf{b}\|}$$
#
# Values range from **-1** (opposite) to **+1** (identical).

# %%
model.eval()

def cosine_similarity(word_a: str, word_b: str) -> float:
    """Compute cosine similarity between two words."""
    if word_a not in word2idx or word_b not in word2idx:
        return float('nan')
    v_a = torch.FloatTensor(model.get_embedding(word2idx[word_a]))
    v_b = torch.FloatTensor(model.get_embedding(word2idx[word_b]))
    return F.cosine_similarity(v_a.unsqueeze(0), v_b.unsqueeze(0)).item()


word_pairs = [
    ('България', 'Русия'),
    ('България', 'Европа'),
    ('война', 'мир'),
    ('хора', 'хората'),
    ('Обама', 'Тръмп'),
]

print(f'{'Word A':15s}  {'Word B':15s}  Cosine sim')
print('-' * 45)
for a, b in word_pairs:
    sim = cosine_similarity(a, b)
    print(f'{a:15s}  {b:15s}  {sim:.4f}')
# Out:
# Word A           Word B           Cosine sim
# ---------------------------------------------
# България         Русия            0.5035
# България         Европа           0.3697
# война            мир              nan
# хора             хората           0.4456
# Обама            Тръмп            -0.0068

# %% [markdown]
# ### 6.2 Nearest Neighbours

# %%
def nearest_neighbours(word: str, k: int = 10) -> list:
    """Return the k most similar words to `word`."""
    if word not in word2idx:
        print(f'Word "{word}" not in vocabulary')
        return []
    word_tensor = torch.LongTensor([[word2idx[word]]]).to(device)
    nn_ids      = model.get_nearest(word_tensor, top_k=k).cpu().numpy()[0]
    return [idx2word[i] for i in nn_ids]


query_words = ['България', 'война', 'Обама', 'хора']

for q in query_words:
    nn = nearest_neighbours(q, k=8)
    print(f'{q:15s}  →  {nn}')
# Out:
# България         →  ['че', 'да', 'не', 'е', 'ще', 'UNK', 'на', 'в']
# война            →  ['но', 'в', 'това', 'което', 'за', 'с', 'са', 'UNK']
# Обама            →  ['правата', 'слаби', 'разстояние', 'Девраха', '31', 'паяжина', 'я', 'Ашкенази']
# хора             →  ['за', 'по', 'на', 'и', 'UNK', 'да', 'в', 'че']

# %% [markdown]
# ### 6.3 Word Analogies
#
# The famous embedding property:
#
# ```
# king − man + woman ≈ queen
# ```
#
# We implement: *a is to b as c is to __?__*
#
# $$\mathbf{v}_{answer} \approx \mathbf{v}_b - \mathbf{v}_a + \mathbf{v}_c$$

# %%
def word_analogy(a: str, b: str, c: str, k: int = 5) -> list:
    """
    Answer the analogy: a is to b as c is to ?
    Returns the top-k most similar words to  v(b) - v(a) + v(c).
    """
    for w in [a, b, c]:
        if w not in word2idx:
            print(f'  ⚠  Word "{w}" not in vocabulary')
            return []

    v_a = torch.FloatTensor(model.get_embedding(word2idx[a]))
    v_b = torch.FloatTensor(model.get_embedding(word2idx[b]))
    v_c = torch.FloatTensor(model.get_embedding(word2idx[c]))

    target_vec = v_b - v_a + v_c   # analogy vector

    # Compare against all embeddings
    all_emb = model.u_embeddings.weight.cpu()          # (V, D)
    target_norm = F.normalize(target_vec.unsqueeze(0), p=2, dim=1)  # (1, D)
    all_norm    = F.normalize(all_emb, p=2, dim=1)                  # (V, D)

    sims = torch.mm(target_norm, all_norm.T).squeeze(0)  # (V,)

    # Exclude a, b, c from results
    for exclude in [word2idx[a], word2idx[b], word2idx[c]]:
        sims[exclude] = -1.0

    top_ids = torch.topk(sims, k).indices.numpy()
    return [idx2word[i] for i in top_ids]


print('Analogy: Обама → САЩ,  Русия → ?')
print(word_analogy('Обама', 'САЩ', 'Русия'))

print('\nAnalogy: Левски → България,  Русия → ?')
print(word_analogy('Левски', 'България', 'Русия'))
# Out:
# Analogy: Обама → САЩ,  Русия → ?
# ['по', 'има', 'UNK', 'се', 'и']
#
# Analogy: Левски → България,  Русия → ?
# ['са', 'се', 'да', 'на', 'UNK']

# %% [markdown]
# **Note:** Analogies work best with very large corpora. On a small news dataset results will be noisy — this is expected and worth discussing!

# %% [markdown]
# ---
# ## Embedding Visualisation
#
# Embeddings live in a 100-dimensional space — we use **t-SNE** to project them into 2D.
#
# t-SNE (t-distributed Stochastic Neighbour Embedding) tries to preserve local structure:
# words that are close in 100D should stay close in 2D.

# %%
# ── Extract embedding matrix ──────────────────────────────────────────────────
with torch.no_grad():
    embedding_matrix = model.u_embeddings.weight.cpu().numpy()   # (V, D)

print(f'Embedding matrix shape: {embedding_matrix.shape}')

# ── Select interesting words for visualisation ────────────────────────────────
viz_words = [
    # Countries / places
    'България', 'Русия', 'Европа', 'Америка', 'САЩ', 'Москва',
    # Politics
    'президент', 'Обама', 'Тръмп', 'НАТО', 'война', 'партия', 'избори',
    # People
    'хора', 'хората', 'човек',
    # Common verbs / concepts
    'може', 'трябва', 'няма', 'има', 'свят',
]

# Keep only those in vocabulary
viz_words  = [w for w in viz_words if w in word2idx]
viz_ids    = [word2idx[w] for w in viz_words]
viz_matrix = embedding_matrix[viz_ids]   # (N, D)

print(f'Visualising {len(viz_words)} words')
# Out:
# Embedding matrix shape: (5000, 100)
# Visualising 21 words

# %%
# ── t-SNE projection ──────────────────────────────────────────────────────────
# First reduce with PCA to speed up t-SNE
pca   = PCA(n_components=min(50, len(viz_words) - 1))
pca_emb = pca.fit_transform(viz_matrix)

tsne  = TSNE(n_components=2, perplexity=min(5, len(viz_words) // 2),
             random_state=SEED)
coords = tsne.fit_transform(pca_emb)   # (N, 2)

# ── Plot ──────────────────────────────────────────────────────────────────────
plt.figure(figsize=(12, 8))
plt.scatter(coords[:, 0], coords[:, 1], s=60, alpha=0.7, color='steelblue')

for i, word in enumerate(viz_words):
    plt.annotate(
        word,
        xy=(coords[i, 0], coords[i, 1]),
        xytext=(5, 3),
        textcoords='offset points',
        fontsize=11
    )

plt.title('Word Embeddings — t-SNE Projection', fontsize=14)
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 7.2 Similarity Heatmap

# %%
# ── Cosine similarity matrix for a subset of words ───────────────────────────
subset_words = ['България', 'Русия', 'Европа', 'Обама', 'Тръмп', 'война', 'мир', 'хора', 'свят']
subset_words = [w for w in subset_words if w in word2idx]
subset_ids   = [word2idx[w] for w in subset_words]
subset_mat   = embedding_matrix[subset_ids]

# L2-normalise
subset_norm = subset_mat / (np.linalg.norm(subset_mat, axis=1, keepdims=True) + 1e-9)
sim_matrix  = subset_norm @ subset_norm.T

fig, ax = plt.subplots(figsize=(8, 7))
im = ax.imshow(sim_matrix, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(im, ax=ax, label='Cosine similarity')

ax.set_xticks(range(len(subset_words)))
ax.set_yticks(range(len(subset_words)))
ax.set_xticklabels(subset_words, rotation=45, ha='right')
ax.set_yticklabels(subset_words)

# Annotate cells
for i in range(len(subset_words)):
    for j in range(len(subset_words)):
        ax.text(j, i, f'{sim_matrix[i,j]:.2f}', ha='center', va='center',
                fontsize=8, color='black')

ax.set_title('Pairwise Cosine Similarity', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Part 8 — Saving & Loading Embeddings

# %%
# ── Save model checkpoint ─────────────────────────────────────────────────────
checkpoint = {
    'model_state_dict': model.state_dict(),
    'vocab_size':       VOCAB_SIZE,
    'emb_size':         EMBEDDING_DIM,
    'word2idx':         word2idx,
    'idx2word':         idx2word,
}
torch.save(checkpoint, 'word2vec_checkpoint.pt')
print('Model saved to word2vec_checkpoint.pt')

# ── Save embeddings as a text file (word2vec format) ──────────────────────────
with open('embeddings.txt', 'w', encoding='utf-8') as f:
    f.write(f'{VOCAB_SIZE} {EMBEDDING_DIM}\n')
    for idx in range(VOCAB_SIZE):
        word   = idx2word[idx]
        vector = embedding_matrix[idx]
        vec_str = ' '.join(f'{v:.6f}' for v in vector)
        f.write(f'{word} {vec_str}\n')

print('Embeddings saved to embeddings.txt  (word2vec text format)')

# %%
# ── Reload and verify ─────────────────────────────────────────────────────────
ckpt   = torch.load('word2vec_checkpoint.pt', map_location=device)

model2 = SkipGram(ckpt['vocab_size'], ckpt['emb_size']).to(device)
model2.load_state_dict(ckpt['model_state_dict'])
model2.eval()

w2i_loaded = ckpt['word2idx']
i2w_loaded = ckpt['idx2word']

# Spot check
test_word = 'България'
if test_word in w2i_loaded:
    tid  = torch.LongTensor([[w2i_loaded[test_word]]]).to(device)
    nbs  = model2.get_nearest(tid, top_k=5).cpu().numpy()[0]
    print(f'Loaded model — nearest to "{test_word}": {[i2w_loaded[n] for n in nbs]}')
    print('Model loaded successfully!')

# %% [markdown]
# ---
# ## Part 9 — Downstream Task: Subjectivity Classification
#
# Now that we have trained word embeddings, we put them to work on a **real NLP task**:
# detecting whether a Bulgarian sentence is *subjective* (SUBJ) or *objective* (OBJ).
#
# ### Pipeline
#
# ```
# Sentence
#    │
#    ▼  tokenise
# Word list
#    │
#    ▼  look up trained embeddings  → mean-pool
# Sentence vector  (D-dimensional)
#    │
#    ▼  Logistic Regression  (trained on train split)
# Label: SUBJ / OBJ
# ```
#
# **Why mean-pooling?**
# It is simple, fast, and surprisingly effective as a sentence representation baseline.
# It treats the sentence as a *bag of embeddings* — order is lost, but semantic content is preserved.
#
# **Why Logistic Regression on top?**
# We want to isolate the quality of the *embeddings*. A lightweight classifier ensures that
# performance differences come from the representations, not from a powerful classifier.
# We also compare against a TF-IDF baseline to see how much embeddings help.

# %%
# ── 9.1  Sentence-embedding function ─────────────────────────────────────────

model.eval()

def sentence_embedding(sentence: str,
                        emb_model,
                        w2i: dict,
                        emb_dim: int) -> np.ndarray:
    """
    Represent a sentence as the mean of its word embeddings.

    Words not in the vocabulary are silently skipped.
    If *no* words are found (all OOV), returns a zero vector.

    Parameters
    ----------
    sentence  : raw text string
    emb_model : trained SkipGram instance
    w2i       : word -> id dictionary
    emb_dim   : embedding dimensionality

    Returns
    -------
    np.ndarray of shape (emb_dim,)
    """
    tokens = word_tokenize(sentence)
    tokens = [w for w in tokens if w not in PUNCTUATION]

    vectors = []
    with torch.no_grad():
        for token in tokens:
            if token in w2i:
                idx = torch.LongTensor([w2i[token]]).to(device)
                vec = emb_model.u_embeddings(idx).cpu().numpy()[0]
                vectors.append(vec)

    if len(vectors) == 0:
        return np.zeros(emb_dim, dtype=np.float32)

    return np.mean(vectors, axis=0).astype(np.float32)


# Quick sanity check
sample_sent = train_df['sentence'].iloc[0]
emb_vec = sentence_embedding(sample_sent, model, word2idx, EMBEDDING_DIM)
print(f'Sentence : {sample_sent[:80]}...')
print(f'Embedding shape : {emb_vec.shape}')
print(f'L2 norm         : {np.linalg.norm(emb_vec):.4f}')
# Out:
# Sentence : "Трудно е класически оркестър и рок банда да свирят заедно, имаме физически проб...
# Embedding shape : (100,)
# L2 norm         : 0.1046

# %%
# ── 9.2  Build feature matrices for all splits ───────────────────────────────
from tqdm import tqdm as tqdm_bar

def build_features(df: pd.DataFrame,
                   emb_model,
                   w2i: dict,
                   emb_dim: int) -> tuple:
    """
    Convert every sentence in `df` to a mean embedding vector.
    Returns X (n_samples, emb_dim) and y (n_samples,) as numpy arrays.
    """
    X, y = [], []
    for _, row in tqdm_bar(df.iterrows(), total=len(df), leave=False):
        X.append(sentence_embedding(row['sentence'], emb_model, w2i, emb_dim))
        y.append(1 if row['label'] == 'SUBJ' else 0)
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.int64)


print('Building feature matrices...')
X_train, y_train = build_features(train_df, model, word2idx, EMBEDDING_DIM)
X_val,   y_val   = build_features(val_df,   model, word2idx, EMBEDDING_DIM)
X_test,  y_test  = build_features(test_df,  model, word2idx, EMBEDDING_DIM)

print(f'X_train : {X_train.shape}   y_train : {y_train.shape}')
print(f'X_val   : {X_val.shape}   y_val   : {y_val.shape}')
print(f'X_test  : {X_test.shape}   y_test  : {y_test.shape}')
# Out:
# Building feature matrices...
# X_train : (801, 100)   y_train : (801,)
# X_val   : (246, 100)   y_val   : (246,)
# X_test  : (250, 100)   y_test  : (250,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_val_sc   = scaler.transform(X_val)
X_test_sc  = scaler.transform(X_test)

C_candidates = [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]
val_results  = []

for C in C_candidates:
    clf = LogisticRegression(C=C, max_iter=1000, random_state=SEED)
    clf.fit(X_train_sc, y_train)
    val_f1 = f1_score(y_val, clf.predict(X_val_sc), average='macro')
    val_results.append((C, val_f1))
    print(f'  C={C:6.2f}  →  val macro-F1: {val_f1:.4f}')

best_C, best_val_f1 = max(val_results, key=lambda x: x[1])
print(f'\nBest C = {best_C}  (val macro-F1 = {best_val_f1:.4f})')
# Out:
#   C=  0.01  →  val macro-F1: 0.4764
#   C=  0.10  →  val macro-F1: 0.5521
#   C=  0.50  →  val macro-F1: 0.5572
#   C=  1.00  →  val macro-F1: 0.5422
#   C=  5.00  →  val macro-F1: 0.5250
#   C= 10.00  →  val macro-F1: 0.5284
#
# Best C = 0.5  (val macro-F1 = 0.5572)

# %%
# Retrain on train+val with best C, evaluate on test

# Combine train + val for final training (best practice after C selection)
X_trainval_sc = np.vstack([X_train_sc, X_val_sc])
y_trainval    = np.concatenate([y_train, y_val])

final_clf = LogisticRegression(C=best_C, max_iter=1000, random_state=SEED)
final_clf.fit(X_trainval_sc, y_trainval)

y_pred = final_clf.predict(X_test_sc)

test_acc    = accuracy_score(y_test, y_pred)
test_f1_mac = f1_score(y_test, y_pred, average='macro')
test_f1_sub = f1_score(y_test, y_pred, pos_label=1, average='binary')
test_f1_obj = f1_score(y_test, y_pred, pos_label=0, average='binary')

print('=' * 45)
print('  TEST SET RESULTS  (Word2Vec + LogReg)')
print('=' * 45)
print(f'  Accuracy        : {test_acc:.4f}')
print(f'  Macro F1        : {test_f1_mac:.4f}')
print(f'  F1  SUBJ        : {test_f1_sub:.4f}')
print(f'  F1  OBJ         : {test_f1_obj:.4f}')
print('=' * 45)
# Out:
# ...
#   TEST SET RESULTS  (Word2Vec + LogReg)
# ...
#   Accuracy        : 0.5440
#   Macro F1        : 0.5265
#   F1  SUBJ        : 0.4356
#   F1  OBJ         : 0.6174
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

tfidf_pipe = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=10000, sublinear_tf=True)),
    ('clf',   LogisticRegression(C=1.0, max_iter=1000, random_state=SEED))
])

tfidf_val_results = []
for C in C_candidates:
    pipe = Pipeline([
        ('tfidf', TfidfVectorizer(max_features=10000, sublinear_tf=True)),
        ('clf',   LogisticRegression(C=C, max_iter=1000, random_state=SEED))
    ])
    pipe.fit(train_df['sentence'], y_train)
    preds = pipe.predict(val_df['sentence'])
    tfidf_val_results.append((C, f1_score(y_val, preds, average='macro')))

best_C_tfidf, _ = max(tfidf_val_results, key=lambda x: x[1])

tfidf_final = Pipeline([
    ('tfidf', TfidfVectorizer(max_features=10000, sublinear_tf=True)),
    ('clf',   LogisticRegression(C=best_C_tfidf, max_iter=1000, random_state=SEED))
])
tfidf_final.fit(
    pd.concat([train_df, val_df])['sentence'],
    y_trainval
)

y_pred_tfidf    = tfidf_final.predict(test_df['sentence'])
tfidf_acc       = accuracy_score(y_test, y_pred_tfidf)
tfidf_f1_mac    = f1_score(y_test, y_pred_tfidf, average='macro')
tfidf_f1_sub    = f1_score(y_test, y_pred_tfidf, pos_label=1, average='binary')
tfidf_f1_obj    = f1_score(y_test, y_pred_tfidf, pos_label=0, average='binary')

print('=' * 45)
print('  TEST SET RESULTS  (TF-IDF + LogReg)')
print('=' * 45)
print(f'  Accuracy        : {tfidf_acc:.4f}')
print(f'  Macro F1        : {tfidf_f1_mac:.4f}')
print(f'  F1  SUBJ        : {tfidf_f1_sub:.4f}')
print(f'  F1  OBJ         : {tfidf_f1_obj:.4f}')
print('=' * 45)
# Out:
# ...
#   TEST SET RESULTS  (TF-IDF + LogReg)
# ...
#   Accuracy        : 0.6720
#   Macro F1        : 0.6694
#   F1  SUBJ        : 0.6404
#   F1  OBJ         : 0.6985
# ...

# %%
# ── 9.7  Side-by-side comparison ─────────────────────────────────────────────
import pandas as pd

results = pd.DataFrame({
    'Model': ['TF-IDF + LogReg (baseline)', 'Word2Vec + LogReg'],
    'Accuracy':  [tfidf_acc,    test_acc],
    'Macro F1':  [tfidf_f1_mac, test_f1_mac],
    'F1 (SUBJ)': [tfidf_f1_sub, test_f1_sub],
    'F1 (OBJ)':  [tfidf_f1_obj, test_f1_obj],
})
results = results.set_index('Model').round(4)
print(results.to_string())

# Bar chart
metrics = ['Accuracy', 'Macro F1', 'F1 (SUBJ)', 'F1 (OBJ)']
x = np.arange(len(metrics))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))
bars1 = ax.bar(x - width/2, results.loc['TF-IDF + LogReg (baseline)', metrics],
               width, label='TF-IDF + LogReg', color='coral', alpha=0.85)
bars2 = ax.bar(x + width/2, results.loc['Word2Vec + LogReg', metrics],
               width, label='Word2Vec + LogReg', color='steelblue', alpha=0.85)

ax.set_ylabel('Score')
ax.set_title('TF-IDF vs Word2Vec — Subjectivity Classification (Test Set)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.set_ylim(0, 1.05)
ax.legend()
ax.yaxis.grid(True, alpha=0.3)

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f'{bar.get_height():.3f}', ha='center', va='bottom', fontsize=9)
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f'{bar.get_height():.3f}', ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

print('\n Discussion:')
delta = test_f1_mac - tfidf_f1_mac
direction = 'higher' if delta > 0 else 'lower'
print(f'  Word2Vec macro-F1 is {abs(delta):.4f} {direction} than TF-IDF.')
print('  TF-IDF benefits from exact keyword matching.')
print('  Word2Vec can generalise via synonyms, but needs more data to shine.')
# Out:
#                             Accuracy  Macro F1  F1 (SUBJ)  F1 (OBJ)
# Model
# TF-IDF + LogReg (baseline)     0.672    0.6694     0.6404    0.6985
# Word2Vec + LogReg              0.544    0.5265     0.4356    0.6174
#  Discussion:
#   Word2Vec macro-F1 is 0.1429 lower than TF-IDF.
#   TF-IDF benefits from exact keyword matching.
#   Word2Vec can generalise via synonyms, but needs more data to shine.
